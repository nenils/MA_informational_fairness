# %% [markdown]
# ## Home Loan Application Analysis using Aequitas
# <a id='top_cell'></a>
# Recent work in the Machine Learning community has raised concerns about the risk of unintended bias in Algorithmic Decision-Making systems, affecting individuals unfairly. While many bias metrics and fairness definitions have been proposed in recent years, the community has not reached a consensus on which definitions and metrics should be used, and there has been very little empirical analyses of real-world problems using the proposed metrics.
#
# We present the Aequitas toolkit as an intuitive addition to the machine learning workflow, enabling users to to seamlessly test models for several bias and fairness metrics in relation to multiple population groups. We believe the tool will faciliate informed and equitable decision-making around developing and deploying predictive risk-assessment tools for both machine learnining practitioners and policymakers, allowing researchers and program managers to answer a host of questions related to machine learning models, including:
#
# - [What biases exist in my model?](#existing_biases)
#     - [What is the distribution of groups, predicted scores, and labels across my dataset?](#xtab)
#     - [What are bias metrics across groups?](#xtab_metrics)
#     - [How do I interpret biases in my model?](#interpret_bias)
#     - [How do I visualize biases in my model?](#bias_viz)
#
# - [What levels of disparity exist between population groups?](#disparities)
#     - [How does the selected reference group affect disparity calculations?](#disparity_calc)
#     - [How do I interpret calculated disparity ratios?](#interpret_disp)
#     - [How do I visualize disparities in my model?](#disparity_viz)
#
# - [How do I assess model fairness??](#fairness)
#     - [How do I interpret parities?](#interpret_fairness)
#     - [How do I visualize bias metric parity?](#fairness_group_viz)
#     - [How do I visualize parity between groups in my model?](#fairness_disp_viz)
#
#
# We apply the Use case pf the home loan appöication dataset from kaggle.
#
# ### Background
#
# The dataset contains information on 614 loan applications, with 13 features including gender, marital status, income, loan amount, credit history, and loan status (https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset). The goal is to build a predictive model to determine the likelihood of loan approval.
#
# #### Problem Statement
# Dreamhouse Loan Company specializes in providing various types of loans across urban, semi-urban, and rural areas. When a loan application is received, the company validates the applicant’s eligibility based on details such as age, house ownership, work experience, loan intent, income, loan amount, and credit history (https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset). The objective is to streamline and automate this process to identify eligible customer segments and optimize loan offerings (https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset).
#
# #### History
# The dataset is part of a broader effort to improve the loan approval process by leveraging data analytics and machine learning. It has been used in various predictive modeling projects to enhance the accuracy and efficiency of loan eligibility assessments (https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset).

# %%
# !pip install "aequitas==1.0.0" &> /dev/null

import pandas as pd
import seaborn as sns
from aequitas.audit import Audit
from aequitas.fairness import Fairness
import aequitas.plot as ap
import numpy as np

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import BinaryLabelDatasetMetric, ClassificationMetric

from IPython.display import Markdown, display
# import warnings; warnings.simplefilter('ignore')

# %matplotlib inline

# %%
path = "/Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/Loan-Approval-Prediction.csv"

from mlp_prediction import *
datasetX, dataset, target, numerical, categorical, x_train, x_test, y_train, y_test = load_and_preprocess_data(path='Loan-Approval-Prediction.csv')
#models, model_list = build_pipeline(numerical, categorical)
x_train_encoded, x_test_encoded, y_train, y_test, Z_train, Z_test, datasetX1, target,Z, dataset_num_headers, scaler = do_it_like_numbers_do(datasetX,target,numerical)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/torch/_functorch/deprecated.py:61: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:39: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   target.replace({'N': 0, 'Y': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:57: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datasetX['Gender'].replace({'Female': 0, 'Male': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:57: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datasetX['Gender'].replace({'Female': 0, 'Male': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:58: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datasetX['Self_Employed'].replace({'No': 0, 'Yes': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:58: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datasetX['Self_Employed'].replace({'No': 0, 'Yes': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:59: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datasetX['Education'].replace({'Not Graduate': 0, 'Graduate': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:59: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datasetX['Education'].replace({'Not Graduate': 0, 'Graduate': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:60: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datasetX['Married'].replace({'No': 0, 'Yes': 1}, inplace=True)
# /Users/nilsness/Desktop/Uni Skripte und Folien/Masterarbeit/Programming/mlp_prediction.py:60: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datasetX['Married'].replace({'No': 0, 'Yes': 1}, inplace=True)

# %%
dataset_num_headers
# Out:
#      Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 1         1        1          1              0         0.054830
# 2         1        1          1              1         0.035250
# 3         1        1          0              0         0.030093
# 4         1        0          1              0         0.072356
# 5         1        1          1              1         0.065145
# ..      ...      ...        ...            ...              ...
# 609       0        0          1              0         0.034014
# 610       1        1          1              0         0.048930
# 611       1        1          1              0         0.097984
# 612       1        1          1              0         0.091936
# 613       0        0          1              1         0.054830
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Rural  \
# 1             0.044567    0.201354          0.729730             1.0   True
# 2             0.000000    0.096447          0.729730             1.0  False
# 3             0.069687    0.187817          0.729730             1.0  False
# 4             0.000000    0.223350          0.729730             1.0  False
# 5             0.124006    0.436548          0.729730             1.0  False
# ..                 ...         ...               ...             ...    ...
# 609           0.000000    0.104907          0.729730             1.0   True
# 610           0.000000    0.052453          0.324324             1.0   True
# 611           0.007093    0.412860          0.729730             1.0  False
# 612           0.000000    0.301184          0.729730             1.0  False
# 613           0.000000    0.209814          0.729730             0.0  False
#
#      Semiurban  Urban      0      1      2     3+
# 1        False  False  False   True  False  False
# 2        False   True   True  False  False  False
# 3        False   True   True  False  False  False
# 4        False   True   True  False  False  False
# 5        False   True  False  False   True  False
# ..         ...    ...    ...    ...    ...    ...
# 609      False  False   True  False  False  False
# 610      False  False  False  False  False   True
# 611      False   True  False   True  False  False
# 612      False   True  False  False   True  False
# 613       True  False   True  False  False  False
#
# [480 rows x 16 columns]

# %%
p = [{"Gender": 1,"Semiurban":1}]
u = [{"Gender": 0,"Semiurban":0}]
dataset_num_headers.replace({True: 1, False: 0}, inplace=True)
    
dataset_num_headers['Loan_Status'] = target


# Convert dataframe to structured dataset
structured_dataset = StructuredDataset(df=dataset_num_headers, label_names=['Loan_Status'], protected_attribute_names=['Gender','Semiurban'])
structured_dataset_df,dict = structured_dataset.convert_to_dataframe()

ad = BinaryLabelDataset(favorable_label=1.,unfavorable_label=0.,df=structured_dataset_df,label_names=dict['label_names'],protected_attribute_names=dict['protected_attribute_names'])
test, train = ad.split(num_or_size_splits=2)
train.features = scaler.fit_transform(train.features)
test.features = scaler.fit_transform(test.features)

#index = train.feature_names.index("Gender","Semiurban")
# Out:
# /var/folders/xc/73h9x30561961rsyzf84xbvm0000gn/T/ipykernel_58135/783500271.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset_num_headers.replace({True: 1, False: 0}, inplace=True)

# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
sess1_ad = tf.Session()


debiased_model_ad = AdversarialDebiasing(privileged_groups = p,
                        unprivileged_groups = u,
                        scope_name='debiased_classifier',
                        debias=True,
                        sess=sess1_ad)

debiased_model_ad.fit(train)
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2024-03-25 18:01:17.201806: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-25 18:01:17.610622: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# epoch 0; iter: 0; batch classifier loss: 0.798733; batch adversarial loss: 0.858066
# epoch 1; iter: 0; batch classifier loss: 0.785579; batch adversarial loss: 0.821279
# epoch 2; iter: 0; batch classifier loss: 0.769838; batch adversarial loss: 0.859268
# epoch 3; iter: 0; batch classifier loss: 0.755029; batch adversarial loss: 0.865449
# epoch 4; iter: 0; batch classifier loss: 0.764946; batch adversarial loss: 0.872116
# epoch 5; iter: 0; batch classifier loss: 0.747676; batch adversarial loss: 0.890255
# epoch 6; iter: 0; batch classifier loss: 0.727942; batch adversarial loss: 0.864244
# epoch 7; iter: 0; batch classifier loss: 0.723481; batch adversarial loss: 0.873092
# epoch 8; iter: 0; batch classifier loss: 0.711879; batch adversarial loss: 0.875342
# epoch 9; iter: 0; batch classifier loss: 0.701071; batch adversarial loss: 0.914318
# epoch 10; iter: 0; batch classifier loss: 0.698541; batch adversarial loss: 0.901183
# epoch 11; iter: 0; batch classifier loss: 0.693526; batch adversarial loss: 0.873543
# epoch 12; iter: 0; batch classifier loss: 0.671426; batch adversarial loss: 0.903951
# epoch 13; iter: 0; batch classifier loss: 0.690394; batch adversarial loss: 0.910181
# epoch 14; iter: 0; batch classifier loss: 0.671504; batch adversarial loss: 0.914079
# epoch 15; iter: 0; batch classifier loss: 0.671355; batch adversarial loss: 0.937576
# epoch 16; iter: 0; batch classifier loss: 0.651314; batch adversarial loss: 0.951435
# epoch 17; iter: 0; batch classifier loss: 0.649953; batch adversarial loss: 0.955740
# epoch 18; iter: 0; batch classifier loss: 0.641964; batch adversarial loss: 0.959767
# epoch 19; iter: 0; batch classifier loss: 0.633961; batch adversarial loss: 0.960560
# epoch 20; iter: 0; batch classifier loss: 0.619018; batch adversarial loss: 0.954841
# epoch 21; iter: 0; batch classifier loss: 0.606818; batch adversarial loss: 0.957493
# epoch 22; iter: 0; batch classifier loss: 0.599927; batch adversarial loss: 0.982855
# epoch 23; iter: 0; batch classifier loss: 0.615046; batch adversarial loss: 1.007899
# epoch 24; iter: 0; batch classifier loss: 0.591958; batch adversarial loss: 0.972525
# epoch 25; iter: 0; batch classifier loss: 0.589818; batch adversarial loss: 1.014090
# epoch 26; iter: 0; batch classifier loss: 0.593057; batch adversarial loss: 0.988678
# epoch 27; iter: 0; batch classifier loss: 0.576124; batch adversarial loss: 1.002144
# epoch 28; iter: 0; batch classifier loss: 0.574650; batch adversarial loss: 1.011140
# epoch 29; iter: 0; batch classifier loss: 0.556745; batch adversarial loss: 1.019863
# epoch 30; iter: 0; batch classifier loss: 0.554253; batch adversarial loss: 1.037333
# epoch 31; iter: 0; batch classifier loss: 0.566474; batch adversarial loss: 1.060698
# epoch 32; iter: 0; batch classifier loss: 0.541978; batch adversarial loss: 1.091507
# epoch 33; iter: 0; batch classifier loss: 0.557633; batch adversarial loss: 1.023407
# epoch 34; iter: 0; batch classifier loss: 0.544692; batch adversarial loss: 1.028123
# epoch 35; iter: 0; batch classifier loss: 0.538623; batch adversarial loss: 1.088959
# epoch 36; iter: 0; batch classifier loss: 0.545677; batch adversarial loss: 1.088689
# epoch 37; iter: 0; batch classifier loss: 0.499347; batch adversarial loss: 1.070611
# epoch 38; iter: 0; batch classifier loss: 0.548776; batch adversarial loss: 1.080571
# epoch 39; iter: 0; batch classifier loss: 0.532487; batch adversarial loss: 1.133320
# epoch 40; iter: 0; batch classifier loss: 0.531825; batch adversarial loss: 1.029842
# epoch 41; iter: 0; batch classifier loss: 0.552330; batch adversarial loss: 1.137050
# epoch 42; iter: 0; batch classifier loss: 0.536309; batch adversarial loss: 1.121736
# epoch 43; iter: 0; batch classifier loss: 0.508649; batch adversarial loss: 1.035734
# epoch 44; iter: 0; batch classifier loss: 0.507009; batch adversarial loss: 1.093355
# epoch 45; iter: 0; batch classifier loss: 0.509191; batch adversarial loss: 1.088452
# epoch 46; iter: 0; batch classifier loss: 0.473980; batch adversarial loss: 1.071866
# epoch 47; iter: 0; batch classifier loss: 0.487250; batch adversarial loss: 1.092864
# epoch 48; iter: 0; batch classifier loss: 0.472062; batch adversarial loss: 1.115438
# epoch 49; iter: 0; batch classifier loss: 0.513571; batch adversarial loss: 1.137636

# %%
dataset_predict = debiased_model_ad.predict(ad)


prediction_rounded = np.where(dataset_predict.scores > 0.5, int(1), int(0))

# %%
one_instance = test.subset(indexes=[])
print(one_instance)
# Out:
#   Cell In[85], line 1
#     one_instance = test.subset(indexes=[3:5])
#                                          ^
# SyntaxError: invalid syntax

# %%
prediction = debiased_model_ad.predict(one_instance)

# %%
prediction.scores
# Out:
# array([[0.6782819]])

# %%
label_metrics_dataset_predict = BinaryLabelDatasetMetric(dataset_predict, unprivileged_groups=u, privileged_groups=p)

class_metrics_dataset_predict = ClassificationMetric(ad, dataset_predict, unprivileged_groups=u, privileged_groups=p)

# %%
print("Disparate impact of Adversarial Model Predictions is: %f" % label_metrics_dataset_predict.disparate_impact())
print("\n")
print("Mean difference in statistical parity between groups: %f" % label_metrics_dataset_predict.mean_difference())
print("\n")
print("Individual fairness metric that measures similarity of labels to similar instances: %f" % label_metrics_dataset_predict.consistency(20))
print("\n")
print("Number of Instances: %f" % label_metrics_dataset_predict.num_instances())
print("\n")
print("Number of Positive Values: %f" % label_metrics_dataset_predict.num_positives())
print("\n")
print("Number of Negative Values: %f" % label_metrics_dataset_predict.num_negatives())
print("\n")

print(Markdown("### Classification Metrics for the Predictions against the dataset"))

print("Accuracy: %f" % class_metrics_dataset_predict.accuracy())
print("\n")

print("average_odds_difference: %f" % class_metrics_dataset_predict.average_odds_difference())
print("average_predictive_value_difference: %f" % class_metrics_dataset_predict.average_predictive_value_difference())
print("base_rate (P/(P+N)): %f" % class_metrics_dataset_predict.base_rate())
print("error_rate (FP + FN)/(P + N): %f" % class_metrics_dataset_predict.error_rate())
print("false_discovery_rate (FP /(TP + FP)): %f" % class_metrics_dataset_predict.false_discovery_rate())
print("false_negative_rate : %f" % class_metrics_dataset_predict.false_negative_rate())
print("false_negative_rate_difference: %f" % class_metrics_dataset_predict.false_negative_rate_difference())
print("false_positive_rate: %f" % class_metrics_dataset_predict.false_positive_rate())
print("false_positive_rate_difference: %f" % class_metrics_dataset_predict.false_positive_rate_difference())
print("generalized_entropy_index: %f" % class_metrics_dataset_predict.generalized_entropy_index())
print("theil_index: %f" % class_metrics_dataset_predict.theil_index())
print("precision: %f" % class_metrics_dataset_predict.precision())
print("recall: %f" % class_metrics_dataset_predict.recall())
# Out:
# Disparate impact of Adversarial Model Predictions is: 1.000000
#
#
# Mean difference in statistical parity between groups: 0.000000
#
#
# Individual fairness metric that measures similarity of labels to similar instances: 0.958750
#
#
# Number of Instances: 480.000000
#
#
# Number of Positive Values: 460.000000
#
#
# Number of Negative Values: 20.000000
#
#
# <IPython.core.display.Markdown object>
# Accuracy: 0.729167
#
#
# average_odds_difference: 0.000000
# average_predictive_value_difference: -0.127551
# base_rate (P/(P+N)): 0.691667
# error_rate (FP + FN)/(P + N): 0.270833
# false_discovery_rate (FP /(TP + FP)): 0.280435
# false_negative_rate : 0.003012
# false_negative_rate_difference: 0.000000
# false_positive_rate: 0.871622
# false_positive_rate_difference: 0.000000
# generalized_entropy_index: 0.062240
# theil_index: 0.057743
# precision: 0.719565
# recall: 0.996988

# %%
from dice_ml import Dice
import dice_ml
from dice_ml.utils import helpers

d = dice_ml.Data(dataframe=dataset_num_headers, continuous_features=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History'], outcome_name='Loan_Status')

m = dice_ml.Model(model=debiased_model_ad, backend="TF2")

# %%
exp_random = dice_ml.Dice(d, m, method="random")

# %%
query=dataset_num_headers[5:6].drop(columns=['Loan_Status'])

# %%
exp_random.generate_counterfactuals(query_instances=query, total_CFs=4, desired_class="opposite")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 exp_random.generate_counterfactuals(query_instances=query, total_CFs=4, desired_class="opposite")
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/dice_ml/explainer_interfaces/explainer_base.py:186, in ExplainerBase.generate_counterfactuals(self, query_instances, total_CFs, desired_class, desired_range, permitted_range, features_to_vary, stopping_threshold, posthoc_sparsity_param, proximity_weight, sparsity_weight, diversity_weight, categorical_penalty, posthoc_sparsity_algorithm, verbose, **kwargs)
#     184 for query_instance in tqdm(query_instances_list):
#     185     self.data_interface.set_continuous_feature_indexes(query_instance)
# --> 186     res = self._generate_counterfactuals(
#     187         query_instance, total_CFs,
#     188         desired_class=desired_class,
#     189         desired_range=desired_range,
#     190         permitted_range=permitted_range,
#     191         features_to_vary=features_to_vary,
#     192         stopping_threshold=stopping_threshold,
#     193         posthoc_sparsity_param=posthoc_sparsity_param,
#     194         posthoc_sparsity_algorithm=posthoc_sparsity_algorithm,
#     195         verbose=verbose,
#     196         **kwargs)
#     197     res.test_instance_df = self.data_interface.ensure_consistent_type(
#     198             res.test_instance_df, query_instance)
#     199     if res.final_cfs_df is not None and len(res.final_cfs_df) > 0:
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/dice_ml/explainer_interfaces/dice_random.py:78, in DiceRandom._generate_counterfactuals(self, query_instance, total_CFs, desired_range, desired_class, permitted_range, features_to_vary, stopping_threshold, posthoc_sparsity_param, posthoc_sparsity_algorithm, sample_size, random_seed, verbose, limit_steps_ls)
#      74             self.fixed_features_values[feature] = query_instance[feature].iat[0]
#      76 # Do predictions once on the query_instance and reuse across to reduce the number
#      77 # inferences.
# ---> 78 model_predictions = self.predict_fn(query_instance)
#      79 # number of output nodes of ML model
#      80 self.num_output_nodes = None
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/dice_ml/explainer_interfaces/explainer_base.py:517, in ExplainerBase.predict_fn(self, input_instance)
#     514 def predict_fn(self, input_instance):
#     515     """prediction function"""
# --> 517     preds = self.model.get_output(input_instance)
#     518     if self.model.model_type == ModelTypes.Classifier and \
#     519        len(preds.shape) == 1:  # from deep learning predictors
#     520         preds = np.column_stack([1 - preds, preds])
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/dice_ml/model_interfaces/keras_tensorflow_model.py:38, in KerasTensorFlowModel.get_output(self, input_tensor, training, transform_data)
#      36     input_tensor = tf.constant(self.transformer.transform(input_tensor).to_numpy(), dtype=tf.float32)
#      37 if self.backend == 'TF2':
# ---> 38     return self.model(input_tensor, training=training)
#      39 else:
#      40     return self.model(input_tensor)
#
# TypeError: 'AdversarialDebiasing' object is not callable

# %%
dataset['Predictions']=prediction_rounded

# %%
dataset['Predictions']
# Out:
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    1
# Name: Predictions, Length: 480, dtype: int64

# %% [markdown]
# ### Check for disparities in Gender

# %%
aq_palette = sns.diverging_palette(225, 35, n=2)

# %%
df=dataset
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
# 5   Male     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area  Loan_Status  Predictions
# 1         Rural            0            1
# 2         Urban            1            1
# 3         Urban            1            1
# 4         Urban            1            1
# 5         Urban            1            1

# %%
df.Property_Area.unique()
# Out:
# array(['Rural', 'Urban', 'Semiurban'], dtype=object)

# %%
import matplotlib.pyplot as plt

by_race = sns.countplot(x="Gender", hue="Loan_Status", data=df[df.Gender.isin(['Male', 'Female'])], palette=aq_palette)
plt.legend(loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 by_race = sns.countplot(x="Gender", hue="Loan_Status", data=df[df.Gender.isin(['Male', 'Female'])], palette=aq_palette)
#       4 plt.legend(loc='upper right')
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:2954, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2951 if ax is None:
#    2952     ax = plt.gca()
# -> 2954 plotter.plot(ax, kwargs)
#    2955 return ax
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %%
by_marriage = sns.countplot(x="Married", hue="Loan_Status", data=df, palette=aq_palette)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 by_marriage = sns.countplot(x="Married", hue="Loan_Status", data=df, palette=aq_palette)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:2954, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2951 if ax is None:
#    2952     ax = plt.gca()
# -> 2954 plotter.plot(ax, kwargs)
#    2955 return ax
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %%
by_property = sns.countplot(x="Property_Area", hue="Loan_Status", data=df, palette=aq_palette)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 by_property = sns.countplot(x="Property_Area", hue="Loan_Status", data=df, palette=aq_palette)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:2954, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2951 if ax is None:
#    2952     ax = plt.gca()
# -> 2954 plotter.plot(ax, kwargs)
#    2955 return ax
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='disparity_calc'></a>
#
# ### How does the selected reference group affect disparity calculations?
#
# Disparities calculated in the the Aequitas `Bias()` class based on the crosstab returned by the `Group()` class **`get_crosstabs()`** method can be derived using several different base gorups. In addition to using user-specified groups illustrated above, Aequitas can automate base group selection based on dataset characterisitcs:

# %%
label_by_gender = sns.countplot(x="Gender", hue="Predictions", data=df[df.Gender.isin(['Male', 'Female'])], palette=aq_palette)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 label_by_gender = sns.countplot(x="Gender", hue="Predictions", data=df[df.Gender.isin(['Male', 'Female'])], palette=aq_palette)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:2954, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2951 if ax is None:
#    2952     ax = plt.gca()
# -> 2954 plotter.plot(ax, kwargs)
#    2955 return ax
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %%
label_by_marital = sns.countplot(x="Married", hue="Predictions", data=df, palette=aq_palette)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 label_by_marital = sns.countplot(x="Married", hue="Predictions", data=df, palette=aq_palette)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:2954, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2951 if ax is None:
#    2952     ax = plt.gca()
# -> 2954 plotter.plot(ax, kwargs)
#    2955 return ax
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %%
label_by_sex = sns.countplot(x="Property_Area", hue="Predictions", data=df, palette=aq_palette)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 label_by_sex = sns.countplot(x="Property_Area", hue="Predictions", data=df, palette=aq_palette)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:2954, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2951 if ax is None:
#    2952     ax = plt.gca()
# -> 2954 plotter.plot(ax, kwargs)
#    2955 return ax
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %% [markdown]
# The `Fairness()` class includes a method to quickly return a list of fairness determinations from the dataframe returned by the **`get_group_value_fairness()`** method.

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='interpret_fairness'></a>
#
# ### How do I interpret parities?
# Calling the Aequitas `Fairness()` class **`get_group_value_fairness()`** method on the dataframe returned from a `Bias()` class `get_dispariy` method will return the dataframe with additional columns indicating parities, as seen in the slice of the `get_group_value_fairness` data frame directly above.
#
# In this case, our base groups are Male for gender, Urban for property_area, and No for self_employed. By construction, the base group has supervised fairness. (The disparity ratio is 1).
#
# Above, the Female false omission rate is within the bounds of fairness. This result is expected somewhat surprising as the model is just the plain MLPClassifier.
#
# These findings mark an inherent trade-off between FPR Fairness, FNR Fairness and calibration, which is present in any decision system where base rates are not equal. See [Chouldechova (2017)](https://www.andrew.cmu.edu/user/achoulde/files/disparate_impact.pdf). Aequitas helps bring this trade-off to the forefront with clear metrics and asks system designers to make a reasoned decision based on their use case.

# %% [markdown]
# ### Attribute Level Fairness
# Use the **`get_group_attribute_fairness()`** function to view only the calculated parities from the **`get_group_value_fairness()`** function at the attribute level.

# %% [markdown]
# ### Overall Fairness
# The **`get_overall_fairness()`** function gives a quick boolean assessment of the output of **`get_group_value_fairness()`** or **`get_group_attribute_fairness()`**, returning a dictionary with a determination across all attributes for each of:
# - Unsupervised Fairness
# - Supervised Fairness
# - Overall Fairness

# %% [markdown]
# [Back to Top](#top_cell)

# %% [markdown]
# **Note**: The **`get_crosstabs()`** method expects a dataframe with predefined columns `score`, and `label_value` and treats other columns (with a few exceptions) as attributes against which to test for disparities. In this case, we include `race`, `sex` and `age_cat`.

# %%
df.rename(columns={'Loan_Status': 'label_value'}, inplace=True)
df.rename(columns={'Predictions': 'score'}, inplace=True)
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# 5               4196.0       267.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area  label_value  score
# 1           Rural            0      1
# 2           Urban            1      1
# 3           Urban            1      1
# 4           Urban            1      1
# 5           Urban            1      1
# ..            ...          ...    ...
# 609         Rural            1      1
# 610         Rural            1      1
# 611         Urban            1      1
# 612         Urban            1      1
# 613     Semiurban            0      1
#
# [480 rows x 13 columns]

# %%
df['score'] = df['score'].astype(int)

# %%
numerical =['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']


audit = Audit(df.drop(columns=numerical), label_column="label_value")
audit.audit()

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='xtab_metrics'></a>
#
# ### What are bias metrics across groups?
#
# Once you have run the `Group()` class **`get_crosstabs()`** method, you'll have a dataframe of the [group counts](#counts_description) and [group value bias metrics](#counts_description).
#
# The `Group()` class has a **`list_absolute_metrics()`** method, which you can use for faster slicing to view just  counts or bias metrics.

# %% [markdown]
# #### View calculated counts across sample population groups

# %%
audit.confusion_matrix
# Out:
#                                  pp  pn   fp  fn  tn   tp  group_label_pos  \
# attribute_name attribute_value
# Gender         Female            86   0   32   0   0   54               54
#                Male             374  20   97   1  19  277              278
# Married        No               156  13   52   1  12  104              105
#                Yes              304   7   77   0   7  227              227
# Dependents     0                261  13   75   1  12  186              187
#                1                 77   3   25   0   3   52               52
#                2                 82   3   17   0   3   65               65
#                3+                40   1   12   0   1   28               28
# Education      Graduate         373  10  103   1   9  270              271
#                Not Graduate      87  10   26   0  10   61               61
# Self_Employed  No               398  16  110   1  15  288              289
#                Yes               62   4   19   0   4   43               43
# Property_Area  Rural            127  12   43   1  11   84               85
#                Semiurban        191   0   42   0   0  149              149
#                Urban            142   8   44   0   8   98               98
#
#                                 group_label_neg  group_size  total_entities
# attribute_name attribute_value
# Gender         Female                        32          86             480
#                Male                         116         394             480
# Married        No                            64         169             480
#                Yes                           84         311             480
# Dependents     0                             87         274             480
#                1                             28          80             480
#                2                             20          85             480
#                3+                            13          41             480
# Education      Graduate                     112         383             480
#                Not Graduate                  36          97             480
# Self_Employed  No                           125         414             480
#                Yes                           23          66             480
# Property_Area  Rural                         54         139             480
#                Semiurban                     42         191             480
#                Urban                         52         150             480

# %% [markdown]
# #### View calculated absolute metrics for each sample population group

# %%
audit.metrics.round(2)
# Out:
#                                 accuracy   tpr   tnr   for   fdr   fpr   fnr  \
# attribute_name attribute_value
# Gender         Female               0.63  1.00  0.00   NaN  0.37  1.00  0.00
#                Male                 0.75  1.00  0.16  0.05  0.26  0.84  0.00
# Married        No                   0.69  0.99  0.19  0.08  0.33  0.81  0.01
#                Yes                  0.75  1.00  0.08  0.00  0.25  0.92  0.00
# Dependents     0                    0.72  0.99  0.14  0.08  0.29  0.86  0.01
#                1                    0.69  1.00  0.11  0.00  0.32  0.89  0.00
#                2                    0.80  1.00  0.15  0.00  0.21  0.85  0.00
#                3+                   0.71  1.00  0.08  0.00  0.30  0.92  0.00
# Education      Graduate             0.73  1.00  0.08  0.10  0.28  0.92  0.00
#                Not Graduate         0.73  1.00  0.28  0.00  0.30  0.72  0.00
# Self_Employed  No                   0.73  1.00  0.12  0.06  0.28  0.88  0.00
#                Yes                  0.71  1.00  0.17  0.00  0.31  0.83  0.00
# Property_Area  Rural                0.68  0.99  0.20  0.08  0.34  0.80  0.01
#                Semiurban            0.78  1.00  0.00   NaN  0.22  1.00  0.00
#                Urban                0.71  1.00  0.15  0.00  0.31  0.85  0.00
#
#                                  npv  precision   ppr  pprev  prev
# attribute_name attribute_value
# Gender         Female            NaN       0.63  0.19   1.00  0.63
#                Male             0.95       0.74  0.81   0.95  0.71
# Married        No               0.92       0.67  0.34   0.92  0.62
#                Yes              1.00       0.75  0.66   0.98  0.73
# Dependents     0                0.92       0.71  0.57   0.95  0.68
#                1                1.00       0.68  0.17   0.96  0.65
#                2                1.00       0.79  0.18   0.96  0.76
#                3+               1.00       0.70  0.09   0.98  0.68
# Education      Graduate         0.90       0.72  0.81   0.97  0.71
#                Not Graduate     1.00       0.70  0.19   0.90  0.63
# Self_Employed  No               0.94       0.72  0.87   0.96  0.70
#                Yes              1.00       0.69  0.13   0.94  0.65
# Property_Area  Rural            0.92       0.66  0.28   0.91  0.61
#                Semiurban         NaN       0.78  0.42   1.00  0.78
#                Urban            1.00       0.69  0.31   0.95  0.65

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='interpret_bias'></a>
#
# ### How do I interpret biases in my model?
# In the slice of the crosstab dataframe created by the `Group()` class **`get_crosstabs()`** method directly above, we see that African-Americans have a false positive rate (`fpr`) of 45%, while Caucasians have a false positive rate of only 23%. This means that African-American people are far more likely to be falsely labeled as high-risk than white people. On the other hand, false ommision rates (`for`) and false discovery rates (`fdr`) are much closer for those two groups.

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='disparities'></a>
#
# ## What levels of disparity exist between population groups?
#
# ### _Aequitas Bias() Class_
# We use the Aequitas `Bias()` class to calculate disparities between groups based on the crosstab returned by the `Group()` class **`get_crosstabs()`** method described above. Disparities are calculated as a ratio of a metric for a group of interest compared to a base group. For example, the False Negative Rate Disparity for black defendants vis-a-vis whites is:
# $$Disparity_{FNR} =  \frac{FNR_{black}}{FNR_{white}}$$
#
# Below, we use **`get_disparity_predefined_groups()`** which allows us to choose reference groups that clarify the output for the practitioner.
#
# The Aequitas `Bias()` class includes two additional get disparity functions: **`get_disparity_major_group()`** and **`get_disparity_min_metric()`**, which automate base group selection based on sample majority (across each attribute) and minimum value for each calculated bias metric, respectively.
#
# The **`get_disparity_predefined_groups()`** allows user to define a base group for each attribute, as illustrated below.

# %% [markdown]
# #### Disparities Calculated Calcuated:
#
# | Metric | Column Name |
# | --- | --- |
# | True Positive Rate Disparity | 'tpr_disprity' |
# | True Negative Rate | 'tnr_disparity' |
# | False Omission Rate | 'for_disparity' |
# | False Discovery Rate | 'fdr_disparity' |
# | False Positive Rate | 'fpr_disparity' |
# | False NegativeRate | 'fnr_disparity' |
# | Negative Predictive Value | 'npv_disparity' |
# | Precision Disparity | 'precision_disparity' |
# | Predicted Positive Ratio$_k$ Disparity | 'ppr_disparity' |
# | Predicted Positive Ratio$_g$ Disparity | 'pprev_disparity' |
#
#
# Columns for each disparity are appended to the crosstab dataframe, along with a column indicating the reference group for each calculated metric (denoted by `[METRIC NAME]_ref_group_value`). We see a slice of the dataframe with calculated metrics in the next section.

# %% [markdown]
# #### Disparities calculated in relation to a user-specified group for each attribute

# %%
audit = Audit(df.drop(columns=numerical), label_column="label_value",
              reference_groups={'Gender':'Male', 'Married':'Yes','Dependents':'0','Education':'Graduate', 'Self_Employed':'No','Property_Area':'Semiurban'})

audit.audit(bias_args={
    "alpha": 0.05,
    "check_significance": True,
    "mask_significance": True
})

audit.disparity_df.style
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2710: RuntimeWarning: invalid value encountered in double_scalars
#   W = numer / denom
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2710: RuntimeWarning: invalid value encountered in double_scalars
#   W = numer / denom
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2710: RuntimeWarning: invalid value encountered in double_scalars
#   W = numer / denom
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2710: RuntimeWarning: invalid value encountered in double_scalars
#   W = numer / denom
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: invalid value encountered in double_scalars
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: invalid value encountered in double_scalars
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: invalid value encountered in double_scalars
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: invalid value encountered in double_scalars
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, False, False, False, False, False, False, None, False, False, False, False, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, True, False, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, False, False, False, False, False, False, None, False, False, False, False, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, False, False, False, False, False, False, None, False, False, False, False, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, True, False, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[True, False, False, False, False, False, False, False, False, True, False, False, True, None, True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, True, False, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[True, False, False, False, False, False, False, False, False, True, False, False, True, None, True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, False, False, False, False, False, False, None, False, False, False, False, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, True, False, True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, True, False, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:445: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[True, False, False, False, False, False, False, False, False, True, False, False, True, None, True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# <style type="text/css">
# </style>
# <table id="T_8d9fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d9fd_level0_col0" class="col_heading level0 col0" >model_id</th>
#       <th id="T_8d9fd_level0_col1" class="col_heading level0 col1" >score_threshold</th>
#       <th id="T_8d9fd_level0_col2" class="col_heading level0 col2" >k</th>
#       <th id="T_8d9fd_level0_col3" class="col_heading level0 col3" >attribute_name</th>
#       <th id="T_8d9fd_level0_col4" class="col_heading level0 col4" >attribute_value</th>
#       <th id="T_8d9fd_level0_col5" class="col_heading level0 col5" >accuracy</th>
#       <th id="T_8d9fd_level0_col6" class="col_heading level0 col6" >tpr</th>
#       <th id="T_8d9fd_level0_col7" class="col_heading level0 col7" >tnr</th>
#       <th id="T_8d9fd_level0_col8" class="col_heading level0 col8" >for</th>
#       <th id="T_8d9fd_level0_col9" class="col_heading level0 col9" >fdr</th>
#       <th id="T_8d9fd_level0_col10" class="col_heading level0 col10" >fpr</th>
#       <th id="T_8d9fd_level0_col11" class="col_heading level0 col11" >fnr</th>
#       <th id="T_8d9fd_level0_col12" class="col_heading level0 col12" >npv</th>
#       <th id="T_8d9fd_level0_col13" class="col_heading level0 col13" >precision</th>
#       <th id="T_8d9fd_level0_col14" class="col_heading level0 col14" >pp</th>
#       <th id="T_8d9fd_level0_col15" class="col_heading level0 col15" >pn</th>
#       <th id="T_8d9fd_level0_col16" class="col_heading level0 col16" >ppr</th>
#       <th id="T_8d9fd_level0_col17" class="col_heading level0 col17" >pprev</th>
#       <th id="T_8d9fd_level0_col18" class="col_heading level0 col18" >fp</th>
#       <th id="T_8d9fd_level0_col19" class="col_heading level0 col19" >fn</th>
#       <th id="T_8d9fd_level0_col20" class="col_heading level0 col20" >tn</th>
#       <th id="T_8d9fd_level0_col21" class="col_heading level0 col21" >tp</th>
#       <th id="T_8d9fd_level0_col22" class="col_heading level0 col22" >group_label_pos</th>
#       <th id="T_8d9fd_level0_col23" class="col_heading level0 col23" >group_label_neg</th>
#       <th id="T_8d9fd_level0_col24" class="col_heading level0 col24" >group_size</th>
#       <th id="T_8d9fd_level0_col25" class="col_heading level0 col25" >total_entities</th>
#       <th id="T_8d9fd_level0_col26" class="col_heading level0 col26" >prev</th>
#       <th id="T_8d9fd_level0_col27" class="col_heading level0 col27" >label_value_significance</th>
#       <th id="T_8d9fd_level0_col28" class="col_heading level0 col28" >score_significance</th>
#       <th id="T_8d9fd_level0_col29" class="col_heading level0 col29" >fdr_disparity</th>
#       <th id="T_8d9fd_level0_col30" class="col_heading level0 col30" >fdr_ref_group_value</th>
#       <th id="T_8d9fd_level0_col31" class="col_heading level0 col31" >fdr_significance</th>
#       <th id="T_8d9fd_level0_col32" class="col_heading level0 col32" >fnr_disparity</th>
#       <th id="T_8d9fd_level0_col33" class="col_heading level0 col33" >fnr_ref_group_value</th>
#       <th id="T_8d9fd_level0_col34" class="col_heading level0 col34" >fnr_significance</th>
#       <th id="T_8d9fd_level0_col35" class="col_heading level0 col35" >for_disparity</th>
#       <th id="T_8d9fd_level0_col36" class="col_heading level0 col36" >for_ref_group_value</th>
#       <th id="T_8d9fd_level0_col37" class="col_heading level0 col37" >for_significance</th>
#       <th id="T_8d9fd_level0_col38" class="col_heading level0 col38" >fpr_disparity</th>
#       <th id="T_8d9fd_level0_col39" class="col_heading level0 col39" >fpr_ref_group_value</th>
#       <th id="T_8d9fd_level0_col40" class="col_heading level0 col40" >fpr_significance</th>
#       <th id="T_8d9fd_level0_col41" class="col_heading level0 col41" >npv_disparity</th>
#       <th id="T_8d9fd_level0_col42" class="col_heading level0 col42" >npv_ref_group_value</th>
#       <th id="T_8d9fd_level0_col43" class="col_heading level0 col43" >npv_significance</th>
#       <th id="T_8d9fd_level0_col44" class="col_heading level0 col44" >ppr_disparity</th>
#       <th id="T_8d9fd_level0_col45" class="col_heading level0 col45" >ppr_ref_group_value</th>
#       <th id="T_8d9fd_level0_col46" class="col_heading level0 col46" >ppr_significance</th>
#       <th id="T_8d9fd_level0_col47" class="col_heading level0 col47" >pprev_disparity</th>
#       <th id="T_8d9fd_level0_col48" class="col_heading level0 col48" >pprev_ref_group_value</th>
#       <th id="T_8d9fd_level0_col49" class="col_heading level0 col49" >pprev_significance</th>
#       <th id="T_8d9fd_level0_col50" class="col_heading level0 col50" >precision_disparity</th>
#       <th id="T_8d9fd_level0_col51" class="col_heading level0 col51" >precision_ref_group_value</th>
#       <th id="T_8d9fd_level0_col52" class="col_heading level0 col52" >precision_significance</th>
#       <th id="T_8d9fd_level0_col53" class="col_heading level0 col53" >tnr_disparity</th>
#       <th id="T_8d9fd_level0_col54" class="col_heading level0 col54" >tnr_ref_group_value</th>
#       <th id="T_8d9fd_level0_col55" class="col_heading level0 col55" >tnr_significance</th>
#       <th id="T_8d9fd_level0_col56" class="col_heading level0 col56" >tpr_disparity</th>
#       <th id="T_8d9fd_level0_col57" class="col_heading level0 col57" >tpr_ref_group_value</th>
#       <th id="T_8d9fd_level0_col58" class="col_heading level0 col58" >tpr_significance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d9fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d9fd_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8d9fd_row0_col1" class="data row0 col1" >binary 0/1</td>
#       <td id="T_8d9fd_row0_col2" class="data row0 col2" >460</td>
#       <td id="T_8d9fd_row0_col3" class="data row0 col3" >Gender</td>
#       <td id="T_8d9fd_row0_col4" class="data row0 col4" >Female</td>
#       <td id="T_8d9fd_row0_col5" class="data row0 col5" >0.627907</td>
#       <td id="T_8d9fd_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_8d9fd_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_8d9fd_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_8d9fd_row0_col9" class="data row0 col9" >0.372093</td>
#       <td id="T_8d9fd_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_8d9fd_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_8d9fd_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_8d9fd_row0_col13" class="data row0 col13" >0.627907</td>
#       <td id="T_8d9fd_row0_col14" class="data row0 col14" >86</td>
#       <td id="T_8d9fd_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_8d9fd_row0_col16" class="data row0 col16" >0.186957</td>
#       <td id="T_8d9fd_row0_col17" class="data row0 col17" >1.000000</td>
#       <td id="T_8d9fd_row0_col18" class="data row0 col18" >32</td>
#       <td id="T_8d9fd_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_8d9fd_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_8d9fd_row0_col21" class="data row0 col21" >54</td>
#       <td id="T_8d9fd_row0_col22" class="data row0 col22" >54</td>
#       <td id="T_8d9fd_row0_col23" class="data row0 col23" >32</td>
#       <td id="T_8d9fd_row0_col24" class="data row0 col24" >86</td>
#       <td id="T_8d9fd_row0_col25" class="data row0 col25" >480</td>
#       <td id="T_8d9fd_row0_col26" class="data row0 col26" >0.627907</td>
#       <td id="T_8d9fd_row0_col27" class="data row0 col27" >False</td>
#       <td id="T_8d9fd_row0_col28" class="data row0 col28" >True</td>
#       <td id="T_8d9fd_row0_col29" class="data row0 col29" >1.434668</td>
#       <td id="T_8d9fd_row0_col30" class="data row0 col30" >Male</td>
#       <td id="T_8d9fd_row0_col31" class="data row0 col31" >False</td>
#       <td id="T_8d9fd_row0_col32" class="data row0 col32" >0.000000</td>
#       <td id="T_8d9fd_row0_col33" class="data row0 col33" >Male</td>
#       <td id="T_8d9fd_row0_col34" class="data row0 col34" >None</td>
#       <td id="T_8d9fd_row0_col35" class="data row0 col35" >nan</td>
#       <td id="T_8d9fd_row0_col36" class="data row0 col36" >Male</td>
#       <td id="T_8d9fd_row

# %%
bdf = audit.disparity_df

# %% [markdown]
# The `Bias()` class includes a method to quickly return a list of calculated disparities from the dataframe returned by the **`get_disparity_`** methods.

# %%
audit.disparities.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_05105">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05105_level0_col0" class="col_heading level0 col0" >fdr_disparity</th>
#       <th id="T_05105_level0_col1" class="col_heading level0 col1" >fnr_disparity</th>
#       <th id="T_05105_level0_col2" class="col_heading level0 col2" >for_disparity</th>
#       <th id="T_05105_level0_col3" class="col_heading level0 col3" >fpr_disparity</th>
#       <th id="T_05105_level0_col4" class="col_heading level0 col4" >npv_disparity</th>
#       <th id="T_05105_level0_col5" class="col_heading level0 col5" >ppr_disparity</th>
#       <th id="T_05105_level0_col6" class="col_heading level0 col6" >pprev_disparity</th>
#       <th id="T_05105_level0_col7" class="col_heading level0 col7" >precision_disparity</th>
#       <th id="T_05105_level0_col8" class="col_heading level0 col8" >tnr_disparity</th>
#       <th id="T_05105_level0_col9" class="col_heading level0 col9" >tpr_disparity</th>
#       <th id="T_05105_level0_col10" class="col_heading level0 col10" >label_value_significance</th>
#       <th id="T_05105_level0_col11" class="col_heading level0 col11" >score_significance</th>
#       <th id="T_05105_level0_col12" class="col_heading level0 col12" >fdr_significance</th>
#       <th id="T_05105_level0_col13" class="col_heading level0 col13" >fnr_significance</th>
#       <th id="T_05105_level0_col14" class="col_heading level0 col14" >for_significance</th>
#       <th id="T_05105_level0_col15" class="col_heading level0 col15" >fpr_significance</th>
#       <th id="T_05105_level0_col16" class="col_heading level0 col16" >npv_significance</th>
#       <th id="T_05105_level0_col17" class="col_heading level0 col17" >ppr_significance</th>
#       <th id="T_05105_level0_col18" class="col_heading level0 col18" >pprev_significance</th>
#       <th id="T_05105_level0_col19" class="col_heading level0 col19" >precision_significance</th>
#       <th id="T_05105_level0_col20" class="col_heading level0 col20" >tnr_significance</th>
#       <th id="T_05105_level0_col21" class="col_heading level0 col21" >tpr_significance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >attribute_name</th>
#       <th class="index_name level1" >attribute_value</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05105_level0_row0" class="row_heading level0 row0" rowspan="2">Gender</th>
#       <th id="T_05105_level1_row0" class="row_heading level1 row0" >Female</th>
#       <td id="T_05105_row0_col0" class="data row0 col0" >1.434668</td>
#       <td id="T_05105_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_05105_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_05105_row0_col3" class="data row0 col3" >1.195876</td>
#       <td id="T_05105_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_05105_row0_col5" class="data row0 col5" >0.229947</td>
#       <td id="T_05105_row0_col6" class="data row0 col6" >1.053476</td>
#       <td id="T_05105_row0_col7" class="data row0 col7" >0.847788</td>
#       <td id="T_05105_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_05105_row0_col9" class="data row0 col9" >1.003610</td>
#       <td id="T_05105_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_05105_row0_col11" class="data row0 col11" >True</td>
#       <td id="T_05105_row0_col12" class="data row0 col12" >False</td>
#       <td id="T_05105_row0_col13" class="data row0 col13" >None</td>
#       <td id="T_05105_row0_col14" class="data row0 col14" >None</td>
#       <td id="T_05105_row0_col15" class="data row0 col15" >False</td>
#       <td id="T_05105_row0_col16" class="data row0 col16" >None</td>
#       <td id="T_05105_row0_col17" class="data row0 col17" >True</td>
#       <td id="T_05105_row0_col18" class="data row0 col18" >True</td>
#       <td id="T_05105_row0_col19" class="data row0 col19" >False</td>
#       <td id="T_05105_row0_col20" class="data row0 col20" >False</td>
#       <td id="T_05105_row0_col21" class="data row0 col21" >None</td>
#     </tr>
#     <tr>
#       <th id="T_05105_level1_row1" class="row_heading level1 row1" >Male</th>
#       <td id="T_05105_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_05105_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_05105_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_05105_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_05105_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_05105_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_05105_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_05105_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_05105_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_05105_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_05105_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_05105_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_05105_row1_col12" class="data row1 col12" >False</td>
#       <td id="T_05105_row1_col13" class="data row1 col13" >False</td>
#       <td id="T_05105_row1_col14" class="data row1 col14" >False</td>
#       <td id="T_05105_row1_col15" class="data row1 col15" >False</td>
#       <td id="T_05105_row1_col16" class="data row1 col16" >False</td>
#       <td id="T_05105_row1_col17" class="data row1 col17" >False</td>
#       <td id="T_05105_row1_col18" class="data row1 col18" >False</td>
#       <td id="T_05105_row1_col19" class="data row1 col19" >False</td>
#       <td id="T_05105_row1_col20" class="data row1 col20" >False</td>
#       <td id="T_05105_row1_col21" class="data row1 col21" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05105_level0_row2" class="row_heading level0 row2" rowspan="2">Married</th>
#       <th id="T_05105_level1_row2" class="row_heading level1 row2" >No</th>
#       <td id="T_05105_row2_col0" class="data row2 col0" >1.316017</td>
#       <td id="T_05105_row2_col1" class="data row2 col1" >10.000000</td>
#       <td id="T_05105_row2_col2" class="data row2 col2" >10.000000</td>
#       <td id="T_05105_row2_col3" class="data row2 col3" >0.886364</td>
#       <td id="T_05105_row2_col4" class="data row2 col4" >0.923077</td>
#       <td id="T_05105_row2_col5" class="data row2 col5" >0.513158</td>
#       <td id="T_05105_row2_col6" class="data row2 col6" >0.944332</td>
#       <td id="T_05105_row2_col7" class="data row2 col7" >0.892805</td>
#       <td id="T_05105_row2_col8" class="data row2 col8" >2.250000</td>
#       <td id="T_05105_row2_col9" class="data row2 col9" >0.990476</td>
#       <td id="T_05105_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_05105_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_05105_row2_col12" class="data row2 col12" >False</td>
#       <td id="T_05105_row2_col13" class="data row2 col13" >False</td>
#       <td id="T_05105_row2_col14" class="data row2 col14" >False</td>
#       <td id="T_05105_row2_col15" class="data row2 col15" >False</td>
#       <td id="T_05105_row2_col16" class="data row2 col16" >False</

# %%
metrics = ['fpr','fdr']
disparity_tolerance = 1.5

# %% [markdown]
# # Aequitas Visualizations

# %%
audit.summary_plot(metrics=metrics, fairness_threshold=disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/plot/summary_chart.py:372: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   attribute_df.groupby(by=f"{metric}_parity_result")
# alt.VConcatChart(...)

# %% [markdown]
# ### Check for disparities in Gender

# %%
audit.disparity_plot(metrics=metrics, attribute='Gender', fairness_threshold=disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.LayerChart(...)

# %% [markdown]
# #### Check how the fairness threshold maps to the absolute values of each metric

# %%
ap.absolute(bdf, metrics, 'Gender', fairness_threshold = disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.LayerChart(...)

# %% [markdown]
# ### Check for disparities in Sex

# %%
ap.disparity(bdf, metrics, 'Married', fairness_threshold = disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.LayerChart(...)

# %% [markdown]
# #### Check how the fairness threshold maps to the absolute values of each metric

# %%
ap.absolute(bdf, metrics, 'Property_Area', fairness_threshold = disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.LayerChart(...)

# %% [markdown]
# ### Check for disparities in Education, Self_Employed and Dependents

# %%
ap.disparity(bdf, metrics, 'Education', fairness_threshold = disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.LayerChart(...)

# %% [markdown]
# #### Check how the fairness threshold maps to the absolute values of each metric

# %%
ap.absolute(bdf, metrics, 'Dependents', fairness_threshold = disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.LayerChart(...)

# %%
ap.absolute(bdf, metrics, 'Self_Employed', fairness_threshold = disparity_tolerance)
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/vegalite/v5/api.py:405: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.LayerChart(...)

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='interpret_disp'></a>
#
# ### How do I interpret calculated disparity ratios?
# The calculated disparities from the dataframe returned by the `Bias()` class **`get_disparity_`** methods are in relation to a reference group, which will always have a disparity of 1.0.
#
# The differences in False Positive Rates, noted in the discussion of the `Group()` class above, are clarified using the disparity ratio (`fpr_disparity`).
#
# As seen above, False Discovery Rates have a higher disparity (`fdr_disparity`), or fraction of false postives over predicted positive in a group. As reference groups have disparity = 1 by design in Aequitas, the lower disparity is highlighted by the `fdr_disparity` value close to 1.26 for the gender attribute group 'Female' when disparities are calculated using predefined base group 'Male'.

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='disparity_calc'></a>
#
# ### How does the selected reference group affect disparity calculations?
#
# Disparities calculated in the the Aequitas `Bias()` class based on the crosstab returned by the `Group()` class **`get_crosstabs()`** method can be derived using several different base gorups. In addition to using user-specified groups illustrated above, Aequitas can automate base group selection based on dataset characterisitcs:

# %%
from aequitas.group import Group
from aequitas.bias import Bias
b = Bias()
g = Group()
xx = df.drop(columns=numerical)
xtab, _ = g.get_crosstabs(xx)
xx
x_copy = xx.copy()

# %%
xtab
# Out:
#     model_id score_threshold    k attribute_name attribute_value  accuracy  \
# 0          0      binary 0/1  480         Gender          Female  0.627907
# 1          0      binary 0/1  480         Gender            Male  0.705584
# 2          0      binary 0/1  480        Married              No  0.621302
# 3          0      binary 0/1  480        Married             Yes  0.729904
# 4          0      binary 0/1  480     Dependents               0  0.682482
# 5          0      binary 0/1  480     Dependents               1  0.650000
# 6          0      binary 0/1  480     Dependents               2  0.764706
# 7          0      binary 0/1  480     Dependents              3+  0.682927
# 8          0      binary 0/1  480      Education        Graduate  0.707572
# 9          0      binary 0/1  480      Education    Not Graduate  0.628866
# 10         0      binary 0/1  480  Self_Employed              No  0.698068
# 11         0      binary 0/1  480  Self_Employed             Yes  0.651515
# 12         0      binary 0/1  480  Property_Area           Rural  0.611511
# 13         0      binary 0/1  480  Property_Area       Semiurban  0.780105
# 14         0      binary 0/1  480  Property_Area           Urban  0.653333
#
#     tpr  tnr  for       fdr  ...  pprev   fp  fn  tn   tp  group_label_pos  \
# 0   1.0  0.0  NaN  0.372093  ...    1.0   32   0   0   54               54
# 1   1.0  0.0  NaN  0.294416  ...    1.0  116   0   0  278              278
# 2   1.0  0.0  NaN  0.378698  ...    1.0   64   0   0  105              105
# 3   1.0  0.0  NaN  0.270096  ...    1.0   84   0   0  227              227
# 4   1.0  0.0  NaN  0.317518  ...    1.0   87   0   0  187              187
# 5   1.0  0.0  NaN  0.350000  ...    1.0   28   0   0   52               52
# 6   1.0  0.0  NaN  0.235294  ...    1.0   20   0   0   65               65
# 7   1.0  0.0  NaN  0.317073  ...    1.0   13   0   0   28               28
# 8   1.0  0.0  NaN  0.292428  ...    1.0  112   0   0  271              271
# 9   1.0  0.0  NaN  0.371134  ...    1.0   36   0   0   61               61
# 10  1.0  0.0  NaN  0.301932  ...    1.0  125   0   0  289              289
# 11  1.0  0.0  NaN  0.348485  ...    1.0   23   0   0   43               43
# 12  1.0  0.0  NaN  0.388489  ...    1.0   54   0   0   85               85
# 13  1.0  0.0  NaN  0.219895  ...    1.0   42   0   0  149              149
# 14  1.0  0.0  NaN  0.346667  ...    1.0   52   0   0   98               98
#
#     group_label_neg  group_size  total_entities      prev
# 0                32          86             480  0.627907
# 1               116         394             480  0.705584
# 2                64         169             480  0.621302
# 3                84         311             480  0.729904
# 4                87         274             480  0.682482
# 5                28          80             480  0.650000
# 6                20          85             480  0.764706
# 7                13          41             480  0.682927
# 8               112         383             480  0.707572
# 9                36          97             480  0.628866
# 10              125         414             480  0.698068
# 11               23          66             480  0.651515
# 12               54         139             480  0.611511
# 13               42         191             480  0.780105
# 14               52         150             480  0.653333
#
# [15 rows x 27 columns]

# %%
hbdf = b.get_disparity_predefined_groups(xtab, original_df=xx,
                                         ref_groups_dict={'Gender':'Male', 'Married':'Yes','Dependents':'0','Education':'Graduate', 'Self_Employed':'No','Property_Area':'Semiurban'},
                                         alpha=0.05,
                                         check_significance=True,
                                         mask_significance=False,
                                         selected_significance=['fpr', 'for', 'fdr'])
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(

# %%
# View disparity metrics added to dataframe
hbdf[['attribute_name', 'attribute_value'] +
     b.list_disparities(hbdf) + b.list_significance(hbdf)]
# Out:
#    attribute_name attribute_value  fdr_disparity  fnr_disparity  \
# 0          Gender          Female       1.263833            NaN
# 1          Gender            Male       1.000000            NaN
# 2         Married              No       1.402085            NaN
# 3         Married             Yes       1.000000            NaN
# 4      Dependents               0       1.000000            NaN
# 5      Dependents               1       1.102299            NaN
# 6      Dependents               2       0.741041            NaN
# 7      Dependents              3+       0.998598            NaN
# 8       Education        Graduate       1.000000            NaN
# 9       Education    Not Graduate       1.269146            NaN
# 10  Self_Employed              No       1.000000            NaN
# 11  Self_Employed             Yes       1.154182            NaN
# 12  Property_Area           Rural       1.766701            NaN
# 13  Property_Area       Semiurban       1.000000            NaN
# 14  Property_Area           Urban       1.576508            NaN
#
#     for_disparity  fpr_disparity  npv_disparity  ppr_disparity  \
# 0             NaN            1.0            NaN       0.218274
# 1             NaN            1.0            NaN       1.000000
# 2             NaN            1.0            NaN       0.543408
# 3             NaN            1.0            NaN       1.000000
# 4             NaN            1.0            NaN       1.000000
# 5             NaN            1.0            NaN       0.291971
# 6             NaN            1.0            NaN       0.310219
# 7             NaN            1.0            NaN       0.149635
# 8             NaN            1.0            NaN       1.000000
# 9             NaN            1.0            NaN       0.253264
# 10            NaN            1.0            NaN       1.000000
# 11            NaN            1.0            NaN       0.159420
# 12            NaN            1.0            NaN       0.727749
# 13            NaN            1.0            NaN       1.000000
# 14            NaN            1.0            NaN       0.785340
#
#     pprev_disparity  precision_disparity  tnr_disparity  tpr_disparity  \
# 0               1.0             0.889911            NaN            1.0
# 1               1.0             1.000000            NaN            1.0
# 2               1.0             0.851211            NaN            1.0
# 3               1.0             1.000000            NaN            1.0
# 4               1.0             1.000000            NaN            1.0
# 5               1.0             0.952406            NaN            1.0
# 6               1.0             1.120478            NaN            1.0
# 7               1.0             1.000652            NaN            1.0
# 8               1.0             1.000000            NaN            1.0
# 9               1.0             0.888766            NaN            1.0
# 10              1.0             1.000000            NaN            1.0
# 11              1.0             0.933312            NaN            1.0
# 12              1.0             0.783883            NaN            1.0
# 13              1.0             1.000000            NaN            1.0
# 14              1.0             0.837494            NaN            1.0
#
#     label_value_significance  score_significance  fdr_significance  \
# 0                   0.158244                 NaN          0.158244
# 1                   1.000000                 NaN          1.000000
# 2                   1.000000                 NaN          1.000000
# 3                   0.447966                 NaN          0.447966
# 4                   1.000000                 NaN          1.000000
# 5                   0.586470                 NaN          0.586470
# 6                   0.148467                 NaN          0.148467
# 7                   0.995462                 NaN          0.995462
# 8                   1.000000                 NaN          1.000000
# 9                   0.134333                 NaN          0.134333
# 10                  1.000000                 NaN          1.000000
# 11                  0.447966                 NaN          0.447966
# 12                  0.001132                 NaN          0.001132
# 13                  1.000000                 NaN          1.000000
# 14                  0.010495                 NaN          0.010495
#
#     for_significance  fpr_significance
# 0                NaN          0.158244
# 1                NaN          1.000000
# 2                NaN          1.000000
# 3                NaN          0.447966
# 4                NaN          1.000000
# 5                NaN          0.586470
# 6                NaN          0.148467
# 7                NaN          0.995462
# 8                NaN          1.000000
# 9                NaN          0.134333
# 10               NaN          1.000000
# 11               NaN          0.447966
# 12               NaN          0.001132
# 13               NaN          1.000000
# 14               NaN          0.010495

# %% [markdown]
# #### Disparities calculated in relation to sample population majority group (in terms of group prevalence) for each attribute
# The majority population groups for each attribute ('gender', 'property are', 'self employed') in the Home Loan application dataset are 'Male', 'Urban', and 'No'. Using the **`get_disparity_major_group()`** method of calculation allows researchers to quickly evaluate how much more (or less often) other groups are falsely or correctly missclasified as approved or denied in relation to the group they have the most data on.

# %%
majority_bdf = b.get_disparity_major_group(xtab, original_df=xx)

# %%
majority_bdf[['attribute_name', 'attribute_value'] +  b.list_disparities(majority_bdf)]
# Out:
#    attribute_name attribute_value  ppr_disparity  pprev_disparity  \
# 0          Gender          Female       0.218274              1.0
# 1          Gender            Male       1.000000              1.0
# 2         Married              No       0.543408              1.0
# 3         Married             Yes       1.000000              1.0
# 4      Dependents               0       1.000000              1.0
# 5      Dependents               1       0.291971              1.0
# 6      Dependents               2       0.310219              1.0
# 7      Dependents              3+       0.149635              1.0
# 8       Education        Graduate       1.000000              1.0
# 9       Education    Not Graduate       0.253264              1.0
# 10  Self_Employed              No       1.000000              1.0
# 11  Self_Employed             Yes       0.159420              1.0
# 12  Property_Area           Rural       0.727749              1.0
# 13  Property_Area       Semiurban       1.000000              1.0
# 14  Property_Area           Urban       0.785340              1.0
#
#     precision_disparity  fdr_disparity  for_disparity  fpr_disparity  \
# 0              0.889911       1.263833            NaN            1.0
# 1              1.000000       1.000000            NaN            1.0
# 2              0.851211       1.402085            NaN            1.0
# 3              1.000000       1.000000            NaN            1.0
# 4              1.000000       1.000000            NaN            1.0
# 5              0.952406       1.102299            NaN            1.0
# 6              1.120478       0.741041            NaN            1.0
# 7              1.000652       0.998598            NaN            1.0
# 8              1.000000       1.000000            NaN            1.0
# 9              0.888766       1.269146            NaN            1.0
# 10             1.000000       1.000000            NaN            1.0
# 11             0.933312       1.154182            NaN            1.0
# 12             0.783883       1.766701            NaN            1.0
# 13             1.000000       1.000000            NaN            1.0
# 14             0.837494       1.576508            NaN            1.0
#
#     fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity
# 0             NaN            1.0            NaN            NaN
# 1             NaN            1.0            NaN            NaN
# 2             NaN            1.0            NaN            NaN
# 3             NaN            1.0            NaN            NaN
# 4             NaN            1.0            NaN            NaN
# 5             NaN            1.0            NaN            NaN
# 6             NaN            1.0            NaN            NaN
# 7             NaN            1.0            NaN            NaN
# 8             NaN            1.0            NaN            NaN
# 9             NaN            1.0            NaN            NaN
# 10            NaN            1.0            NaN            NaN
# 11            NaN            1.0            NaN            NaN
# 12            NaN            1.0            NaN            NaN
# 13            NaN            1.0            NaN            NaN
# 14            NaN            1.0            NaN            NaN

# %% [markdown]
# #### Disparities calculated in relation to the minimum value for each metric
#
# When you do not have a pre-existing don’t frame of reference or policy context for the dataset (ex: Males or Not self-employed historically favored), you may choose to view disparities in relation to the group with the lowest value for every disparity metric, as then every group's value will be at least 1.0, and relationships can be evaluated more linearly.
#
#
# Note that disparities are much more varied, and may have larger magnitude, when the minimum value per metric is used as a reference group versus one of the other two methods.

# %%
min_metric_bdf = b.get_disparity_min_metric(df=xtab, original_df=xx,
                                            check_significance=True)
min_metric_bdf.style
# Out:
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1633: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1738: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/scipy/stats/_morestats.py:2573: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:595: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, difference_significance_p = stats.ttest_ind(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, True, False, True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# /opt/anaconda3/envs/aiss_cv_exercise_04/lib/python3.9/site-packages/aequitas/bias.py:167: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, significance_cols] = np.select(
# <style type="text/css">
# </style>
# <table id="T_29358">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29358_level0_col0" class="col_heading level0 col0" >model_id</th>
#       <th id="T_29358_level0_col1" class="col_heading level0 col1" >score_threshold</th>
#       <th id="T_29358_level0_col2" class="col_heading level0 col2" >k</th>
#       <th id="T_29358_level0_col3" class="col_heading level0 col3" >attribute_name</th>
#       <th id="T_29358_level0_col4" class="col_heading level0 col4" >attribute_value</th>
#       <th id="T_29358_level0_col5" class="col_heading level0 col5" >accuracy</th>
#       <th id="T_29358_level0_col6" class="col_heading level0 col6" >tpr</th>
#       <th id="T_29358_level0_col7" class="col_heading level0 col7" >tnr</th>
#       <th id="T_29358_level0_col8" class="col_heading level0 col8" >for</th>
#       <th id="T_29358_level0_col9" class="col_heading level0 col9" >fdr</th>
#       <th id="T_29358_level0_col10" class="col_heading level0 col10" >fpr</th>
#       <th id="T_29358_level0_col11" class="col_heading level0 col11" >fnr</th>
#       <th id="T_29358_level0_col12" class="col_heading level0 col12" >npv</th>
#       <th id="T_29358_level0_col13" class="col_heading level0 col13" >precision</th>
#       <th id="T_29358_level0_col14" class="col_heading level0 col14" >pp</th>
#       <th id="T_29358_level0_col15" class="col_heading level0 col15" >pn</th>
#       <th id="T_29358_level0_col16" class="col_heading level0 col16" >ppr</th>
#       <th id="T_29358_level0_col17" class="col_heading level0 col17" >pprev</th>
#       <th id="T_29358_level0_col18" class="col_heading level0 col18" >fp</th>
#       <th id="T_29358_level0_col19" class="col_heading level0 col19" >fn</th>
#       <th id="T_29358_level0_col20" class="col_heading level0 col20" >tn</th>
#       <th id="T_29358_level0_col21" class="col_heading level0 col21" >tp</th>
#       <th id="T_29358_level0_col22" class="col_heading level0 col22" >group_label_pos</th>
#       <th id="T_29358_level0_col23" class="col_heading level0 col23" >group_label_neg</th>
#       <th id="T_29358_level0_col24" class="col_heading level0 col24" >group_size</th>
#       <th id="T_29358_level0_col25" class="col_heading level0 col25" >total_entities</th>
#       <th id="T_29358_level0_col26" class="col_heading level0 col26" >prev</th>
#       <th id="T_29358_level0_col27" class="col_heading level0 col27" >label_value_significance</th>
#       <th id="T_29358_level0_col28" class="col_heading level0 col28" >score_significance</th>
#       <th id="T_29358_level0_col29" class="col_heading level0 col29" >fdr_disparity</th>
#       <th id="T_29358_level0_col30" class="col_heading level0 col30" >fdr_ref_group_value</th>
#       <th id="T_29358_level0_col31" class="col_heading level0 col31" >fdr_significance</th>
#       <th id="T_29358_level0_col32" class="col_heading level0 col32" >fnr_disparity</th>
#       <th id="T_29358_level0_col33" class="col_heading level0 col33" >fnr_ref_group_value</th>
#       <th id="T_29358_level0_col34" class="col_heading level0 col34" >fnr_significance</th>
#       <th id="T_29358_level0_col35" class="col_heading level0 col35" >for_disparity</th>
#       <th id="T_29358_level0_col36" class="col_heading level0 col36" >for_ref_group_value</th>
#       <th id="T_29358_level0_col37" class="col_heading level0 col37" >for_significance</th>
#       <th id="T_29358_level0_col38" class="col_heading level0 col38" >fpr_disparity</th>
#       <th id="T_29358_level0_col39" class="col_heading level0 col39" >fpr_ref_group_value</th>
#       <th id="T_29358_level0_col40" class="col_heading level0 col40" >fpr_significance</th>
#       <th id="T_29358_level0_col41" class="col_heading level0 col41" >npv_disparity</th>
#       <th id="T_29358_level0_col42" class="col_heading level0 col42" >npv_ref_group_value</th>
#       <th id="T_29358_level0_col43" class="col_heading level0 col43" >npv_significance</th>
#       <th id="T_29358_level0_col44" class="col_heading level0 col44" >ppr_disparity</th>
#       <th id="T_29358_level0_col45" class="col_heading level0 col45" >ppr_ref_group_value</th>
#       <th id="T_29358_level0_col46" class="col_heading level0 col46" >ppr_significance</th>
#       <th id="T_29358_level0_col47" class="col_heading level0 col47" >pprev_disparity</th>
#       <th id="T_29358_level0_col48" class="col_heading level0 col48" >pprev_ref_group_value</th>
#       <th id="T_29358_level0_col49" class="col_heading level0 col49" >pprev_significance</th>
#       <th id="T_29358_level0_col50" class="col_heading level0 col50" >precision_disparity</th>
#       <th id="T_29358_level0_col51" class="col_heading level0 col51" >precision_ref_group_value</th>
#       <th id="T_29358_level0_col52" class="col_heading level0 col52" >precision_significance</th>
#       <th id="T_29358_level0_col53" class="col_heading level0 col53" >tnr_disparity</th>
#       <th id="T_29358_level0_col54" class="col_heading level0 col54" >tnr_ref_group_value</th>
#       <th id="T_29358_level0_col55" class="col_heading level0 col55" >tnr_significance</th>
#       <th id="T_29358_level0_col56" class="col_heading level0 col56" >tpr_disparity</th>
#       <th id="T_29358_level0_col57" class="col_heading level0 col57" >tpr_ref_group_value</th>
#       <th id="T_29358_level0_col58" class="col_heading level0 col58" >tpr_significance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29358_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29358_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_29358_row0_col1" class="data row0 col1" >binary 0/1</td>
#       <td id="T_29358_row0_col2" class="data row0 col2" >480</td>
#       <td id="T_29358_row0_col3" class="data row0 col3" >Gender</td>
#       <td id="T_29358_row0_col4" class="data row0 col4" >Female</td>
#       <td id="T_29358_row0_col5" class="data row0 col5" >0.627907</td>
#       <td id="T_29358_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_29358_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_29358_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_29358_row0_col9" class="data row0 col9" >0.372093</td>
#       <td id="T_29358_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_29358_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_29358_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_29358_row0_col13" class="data row0 col13" >0.627907</td>
#       <td id="T_29358_row0_col14" class="data row0 col14" >86</td>
#       <td id="T_29358_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_29358_row0_col16" class="data row0 col16" >0.179167</td>
#       <td id="T_29358_row0_col17" class="data row0 col17" >1.000000</td>
#       <td id="T_29358_row0_col18" class="data row0 col18" >32</td>
#       <td id="T_29358_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_29358_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_29358_row0_col21" class="data row0 col21" >54</td>
#       <td id="T_29358_row0_col22" class="data row0 col22" >54</td>
#       <td id="T_29358_row0_col23" class="data row0 col23" >32</td>
#       <td id="T_29358_row0_col24" class="data row0 col24" >86</td>
#       <td id="T_29358_row0_col25" class="data row0 col25" >480</td>
#       <td id="T_29358_row0_col26" class="data row0 col26" >0.627907</td>
#       <td id="T_29358_row0_col27" class="data row0 col27" >False</td>
#       <td id="T_29358_row0_col28" class="data row0 col28" >None</td>
#       <td id="T_29358_row0_col29" class="data row0 col29" >1.263833</td>
#       <td id="T_29358_row0_col30" class="data row0 col30" >Male</td>
#       <td id="T_29358_row0_col31" class="data row0 col31" >False</td>
#       <td id="T_29358_row0_col32" class="data row0 col32" >nan</td>
#       <td id="T_29358_row0_col33" class="data row0 col33" >Female</td>
#       <td id="T_29358_row0_col34" class="data row0 col34" >None</td>
#       <td id="T_29358_row0_col35" class="data row0 col35" >nan</td>
#       <td id="T_29358_row0_col36" class="data row0 col36" >Female</td>
#       <td id="T_29358_row0

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='disparity_viz'></a>
#
# ## How do I visualize disparities in my model?
# To visualize disparities in the dataframe returned by one of the `Bias()` class **`get_disparity_`** methods use one of two methods in the Aequitas `Plot()` class:
#
# A particular disparity metric can be specified with **`plot_disparity()`**. To plot a single disparity, a metric and an attribute must be specified.
#
# Disparities related to a list of particular metrics of interest or `'all'` metrics can be plotted with **`plot_disparity_all()`**.  At least one metric or at least one attribute must be specified when plotting multiple disparities (or the same disparity across multiple attributes). For example, to plot PPR and and Precision disparity for all attributes, specify `metrics=['ppr', 'precision']` with no attribute specified, and to plot default metrics by gender, specify `attributes=['gender']` and with no metrics specified.
#
# **Reference groups are displayed in grey, and always have a disparity = 1.** Note that disparities greater than 10x reference group will are visualized as 10x, and disparities less than 0.1x reference group are visualized as 0.1x.
#
# Statistical siginificance (at a default value of 0.05) is denoted by two asterisks (**) next to a treemap square's value.

# %%
f = Fairness()
fdf = f.get_group_value_fairness(bdf)

# %% [markdown]
# The `Fairness()` class includes a method to quickly return a list of fairness determinations from the dataframe returned by the **`get_group_value_fairness()`** method.

# %%
parity_detrminations = f.list_parities(fdf)

# %%
absolute_metrics= g.absolute_metrics(df=x_copy)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 absolute_metrics= g.absolute_metrics(df=x_copy)
#
# TypeError: 'tuple' object is not callable

# %%
fdf[['attribute_name', 'attribute_value'] + b.list_disparities(fdf) + parity_detrminations].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1b184">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b184_level0_col0" class="col_heading level0 col0" >attribute_name</th>
#       <th id="T_1b184_level0_col1" class="col_heading level0 col1" >attribute_value</th>
#       <th id="T_1b184_level0_col2" class="col_heading level0 col2" >fdr_disparity</th>
#       <th id="T_1b184_level0_col3" class="col_heading level0 col3" >fnr_disparity</th>
#       <th id="T_1b184_level0_col4" class="col_heading level0 col4" >for_disparity</th>
#       <th id="T_1b184_level0_col5" class="col_heading level0 col5" >fpr_disparity</th>
#       <th id="T_1b184_level0_col6" class="col_heading level0 col6" >npv_disparity</th>
#       <th id="T_1b184_level0_col7" class="col_heading level0 col7" >ppr_disparity</th>
#       <th id="T_1b184_level0_col8" class="col_heading level0 col8" >pprev_disparity</th>
#       <th id="T_1b184_level0_col9" class="col_heading level0 col9" >precision_disparity</th>
#       <th id="T_1b184_level0_col10" class="col_heading level0 col10" >tnr_disparity</th>
#       <th id="T_1b184_level0_col11" class="col_heading level0 col11" >tpr_disparity</th>
#       <th id="T_1b184_level0_col12" class="col_heading level0 col12" >FNR Parity</th>
#       <th id="T_1b184_level0_col13" class="col_heading level0 col13" >TPR Parity</th>
#       <th id="T_1b184_level0_col14" class="col_heading level0 col14" >Unsupervised Fairness</th>
#       <th id="T_1b184_level0_col15" class="col_heading level0 col15" >Precision Parity</th>
#       <th id="T_1b184_level0_col16" class="col_heading level0 col16" >Impact Parity</th>
#       <th id="T_1b184_level0_col17" class="col_heading level0 col17" >Statistical Parity</th>
#       <th id="T_1b184_level0_col18" class="col_heading level0 col18" >TypeI Parity</th>
#       <th id="T_1b184_level0_col19" class="col_heading level0 col19" >Supervised Fairness</th>
#       <th id="T_1b184_level0_col20" class="col_heading level0 col20" >TNR Parity</th>
#       <th id="T_1b184_level0_col21" class="col_heading level0 col21" >Equalized Odds</th>
#       <th id="T_1b184_level0_col22" class="col_heading level0 col22" >NPV Parity</th>
#       <th id="T_1b184_level0_col23" class="col_heading level0 col23" >TypeII Parity</th>
#       <th id="T_1b184_level0_col24" class="col_heading level0 col24" >FOR Parity</th>
#       <th id="T_1b184_level0_col25" class="col_heading level0 col25" >FPR Parity</th>
#       <th id="T_1b184_level0_col26" class="col_heading level0 col26" >FDR Parity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b184_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b184_row0_col0" class="data row0 col0" >Gender</td>
#       <td id="T_1b184_row0_col1" class="data row0 col1" >Female</td>
#       <td id="T_1b184_row0_col2" class="data row0 col2" >1.263833</td>
#       <td id="T_1b184_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_1b184_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_1b184_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_1b184_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_1b184_row0_col7" class="data row0 col7" >0.218274</td>
#       <td id="T_1b184_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_1b184_row0_col9" class="data row0 col9" >0.889911</td>
#       <td id="T_1b184_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_1b184_row0_col11" class="data row0 col11" >1.000000</td>
#       <td id="T_1b184_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_1b184_row0_col13" class="data row0 col13" >True</td>
#       <td id="T_1b184_row0_col14" class="data row0 col14" >False</td>
#       <td id="T_1b184_row0_col15" class="data row0 col15" >True</td>
#       <td id="T_1b184_row0_col16" class="data row0 col16" >True</td>
#       <td id="T_1b184_row0_col17" class="data row0 col17" >False</td>
#       <td id="T_1b184_row0_col18" class="data row0 col18" >False</td>
#       <td id="T_1b184_row0_col19" class="data row0 col19" >False</td>
#       <td id="T_1b184_row0_col20" class="data row0 col20" >nan</td>
#       <td id="T_1b184_row0_col21" class="data row0 col21" >True</td>
#       <td id="T_1b184_row0_col22" class="data row0 col22" >nan</td>
#       <td id="T_1b184_row0_col23" class="data row0 col23" >nan</td>
#       <td id="T_1b184_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_1b184_row0_col25" class="data row0 col25" >True</td>
#       <td id="T_1b184_row0_col26" class="data row0 col26" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b184_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b184_row1_col0" class="data row1 col0" >Gender</td>
#       <td id="T_1b184_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_1b184_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_1b184_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_1b184_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_1b184_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_1b184_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_1b184_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_1b184_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_1b184_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_1b184_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_1b184_row1_col11" class="data row1 col11" >1.000000</td>
#       <td id="T_1b184_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_1b184_row1_col13" class="data row1 col13" >True</td>
#       <td id="T_1b184_row1_col14" class="data row1 col14" >True</td>
#       <td id="T_1b184_row1_col15" class="data row1 col15" >True</td>
#       <td id="T_1b184_row1_col16" class="data row1 col16" >True</td>
#       <td id="T_1b184_row1_col17" class="data row1 col17" >True</td>
#       <td id="T_1b184_row1_col18" class="data row1 col18" >True</td>
#       <td id="T_1b184_row1_col19" class="data row1 col19" >False</td>
#       <td id="T_1b184_row1_col20" class="data row1 col20" >nan</td>
#       <td id="T_1b184_row1_col21" class="data row1 col21" >True</td>
#       <td id="T_1b184_row1_col22" class="data row1 col22" >nan</td>
#       <td id="T_1b184_row1_col23" class="data row1 col23" >nan</td>
#       <td id="T_1b184_row1_col24" class="data row1 col24" >nan</td>
#       <td id="T_1b184_row1_col25" class="data row1 col25" >True</td>
#       <td id="T_1b184_row1_col26" class="data row1 col26" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1b184_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b184_row2_col0" class="data row2 col0" >Married</td>
#       <td id="T_1b184_row2_col1" class="data row2 col1" >No</td>
#       <td id="T_1b184_row2_col2" class="data row2 col2" >1.402085</td>
#       <td id="T_1b184_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_1b184_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_1b184_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_1b184_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_1b184_row2_col7" class="data row2 col7" >0.543408</td>
#       <td id="T_1b184_row2_col8" class="data row2 col8" >1.000000</td>
#       <td id="T_1b184_row2_col9" class="data row2 col9" >0.851211</td>
#       <td id="T_1b184_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_1b184_row2_col11" class="data row2 col11" >1.000000</td>
#       <td id="T_1b184_row2_col12" class="data row2 col12" >nan</td>
#       <td id="T_1b184_row2_col13" class="data row2 col13" >True</td>
#       <td id="T_1b184_row2_col14" class="data row2 col14" >False</td>
#       <td id="T_1b184_row2_col15" class="data row2 col15" >True</td>
#       <td id="T_1b184_row2_col16" class="data row2 col16" >True</td>
#       <td id="T_1b184_row2_col17" class="data row2 col17" >False</td>
#       <td id="T_1b184_row2_col18" class="data row2 col18" >False</td>
#       <td id="T_1b184_row2_col19" class="data row2 col19" >False</td>
#       <td id="T_1b184_row2_col20" class="data row2 col20" >nan</td>

# %% [markdown]
# [Back to Top](#top_cell)
# <a id='interpret_fairness'></a>
#
# ### How do I interpret parities?
# Calling the Aequitas `Fairness()` class **`get_group_value_fairness()`** method on the dataframe returned from a `Bias()` class `get_dispariy` method will return the dataframe with additional columns indicating parities, as seen in the slice of the `get_group_value_fairness` data frame directly above.
#
# In this case, our base groups are Male for gender, Urban for property_area, and No for self_employed. By construction, the base group has supervised fairness. (The disparity ratio is 1).
#
# Above, the Female false omission rate is within the bounds of fairness. This result is expected somewhat surprising as the model is just the plain MLPClassifier.
#
# These findings mark an inherent trade-off between FPR Fairness, FNR Fairness and calibration, which is present in any decision system where base rates are not equal. See [Chouldechova (2017)](https://www.andrew.cmu.edu/user/achoulde/files/disparate_impact.pdf). Aequitas helps bring this trade-off to the forefront with clear metrics and asks system designers to make a reasoned decision based on their use case.

# %% [markdown]
# ### Attribute Level Fairness
# Use the **`get_group_attribute_fairness()`** function to view only the calculated parities from the **`get_group_value_fairness()`** function at the attribute level.

# %%
gaf = f.get_group_attribute_fairness(fdf)
gaf
# Out:
#    model_id score_threshold attribute_name  Statistical Parity  Impact Parity  \
# 0         0      binary 0/1     Dependents               False           True
# 1         0      binary 0/1      Education               False           True
# 2         0      binary 0/1         Gender               False           True
# 3         0      binary 0/1        Married               False           True
# 4         0      binary 0/1  Property_Area               False           True
# 5         0      binary 0/1  Self_Employed               False           True
#
#    FDR Parity  FPR Parity  FOR Parity  FNR Parity  TPR Parity  TNR Parity  \
# 0       False        True         NaN         NaN        True         NaN
# 1       False        True         NaN         NaN        True         NaN
# 2       False        True         NaN         NaN        True         NaN
# 3       False        True         NaN         NaN        True         NaN
# 4       False        True         NaN         NaN        True         NaN
# 5        True        True         NaN         NaN        True         NaN
#
#    NPV Parity  Precision Parity  TypeI Parity  TypeII Parity  Equalized Odds  \
# 0         NaN              True         False            NaN            True
# 1         NaN              True         False            NaN            True
# 2         NaN              True         False            NaN            True
# 3         NaN              True         False            NaN            True
# 4         NaN             False         False            NaN            True
# 5         NaN              True          True            NaN            True
#
#    Unsupervised Fairness  Supervised Fairness
# 0                  False                False
# 1                  False                False
# 2                  False                False
# 3                  False                False
# 4                  False                False
# 5                  False                False

# %% [markdown]
# ### Overall Fairness
# The **`get_overall_fairness()`** function gives a quick boolean assessment of the output of **`get_group_value_fairness()`** or **`get_group_attribute_fairness()`**, returning a dictionary with a determination across all attributes for each of:
# - Unsupervised Fairness
# - Supervised Fairness
# - Overall Fairness

# %%
gof = f.get_overall_fairness(fdf)
gof
# Out:
# {'Unsupervised Fairness': False,
#  'Supervised Fairness': False,
#  'Overall Fairness': False}

# %% [markdown]
# [Back to Top](#top_cell)
